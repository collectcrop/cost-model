# %%
import pandas as pd
from io import StringIO


df = pd.read_csv("./result/pgm_disk_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
queries = 1000000

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
walltime_summary = df.groupby("threads")["avg_walltime_s"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# print(walltime_summary)
# Out:
#     threads  avg_latency_ns
# 0         1         95013.1
# 1         2        120597.6
# 2         4        197601.2
# 3         8        408195.6
# 4        16        461689.8
# 5        32        733415.6
# 6        64       1100220.0
# 7       128       2007386.0
# 8       256       3768884.0
# 9       512       7208064.0
# 10     1024      14998080.0
# 11     2048      31994120.0
# 12     4096      69279160.0
# 13     8192     162660600.0
# 14    16384     435021800.0

# %%
df = pd.read_csv("./result/rmi_disk_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
# scale = 2.475268

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
walltime_summary = df.groupby("threads")["avg_walltime_s"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# print(walltime_summary)
# Out:
#     threads  avg_latency_ns
# 0         1    7.120914e+04
# 1         2    9.874272e+04
# 2         4    1.845766e+05
# 3         8    3.128942e+05
# 4        16    4.394600e+05
# 5        32    7.220456e+05
# 6        64    1.200180e+06
# 7       128    2.225594e+06
# 8       256    4.176366e+06
# 9       512    8.006278e+06
# 10     1024    1.643020e+07
# 11     2048    3.463054e+07
# 12     4096    8.552868e+07
# 13     8192    1.963460e+08
# 14    16384    4.913666e+08

# %%
df = pd.read_csv("./result/aulid_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
walltime_summary = df.groupby("threads")["avg_walltime_s"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# print(walltime_summary)
# Out:
#     threads  avg_latency_ns
# 0         1    1.318912e+05
# 1         2    1.529205e+05
# 2         4    1.623418e+05
# 3         8    1.858974e+05
# 4        16    2.373610e+05
# 5        32    3.045400e+05
# 6        64    4.662289e+05
# 7       128    8.379302e+05
# 8       256    1.623724e+06
# 9       512    3.275399e+06
# 10     1024    7.162342e+06
# 11     2048    1.470590e+07
# 12     4096    3.135913e+07
# 13     8192    6.435150e+07
# 14    16384    1.541873e+08

# %%
df = pd.read_csv("./result/bptree_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
scale = 3

df["IOPS"] = fixed_ios*scale / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# Out:
#     threads  avg_latency_ns
# 0         1       178051.37
# 1         2        96944.75
# 2         4        59188.10
# 3         8        41706.99
# 4        16        40131.40
# 5        32        40138.11
# 6        64        40061.42
# 7       128        40040.16
# 8       256        40034.50
# 9       512        39962.70
# 10     1024        40100.53
# 11     2048        40033.50
# 12     4096        40028.82
# 13     8192        40035.16
# 14    16384        40054.10
