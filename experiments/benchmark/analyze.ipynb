# %%
import pandas as pd
from io import StringIO


df = pd.read_csv("./result/pgm_disk_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
queries = 1000000

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()

print(iops_summary)
print(latency_summary)
# Out:
#     threads          IOPS
# 0         1  10036.694777
# 1         2  12283.309596
# 2         4  16058.327753
# 3         8  20381.482398
# 4        16  27779.821434
# 5        32  28641.797318
# 6        64  28353.475460
# 7       128  29855.225012
# 8       256  31562.186307
# 9       512  34055.477942
# 10     1024  34690.309228
# 11     2048  35128.856515
# 12     4096  35647.028762
# 13     8192  35458.966934
# 14    16384  35764.893674
#     threads  avg_latency_ns
# 0         1    9.984804e+04
# 1         2    1.164067e+05
# 2         4    2.014138e+05
# 3         8    3.438220e+05
# 4        16    4.773230e+05
# 5        32    6.916728e+05
# 6        64    1.099226e+06
# 7       128    2.003284e+06
# 8       256    3.774460e+06
# 9       512    7.160326e+06
# 10     1024    1.534726e+07
# 11     2048    3.008330e+07
# 12     4096    6.649790e+07
# 13     8192    1.549198e+08
# 14    16384    3.815404e+08

# %%
df = pd.read_csv("./result/rmi_disk_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
# scale = 2.475268

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# Out:
#     threads  avg_latency_ns
# 0         1    7.763420e+04
# 1         2    9.370057e+04
# 2         4    1.736668e+05
# 3         8    3.239418e+05
# 4        16    4.379038e+05
# 5        32    7.041998e+05
# 6        64    1.188840e+06
# 7       128    2.223636e+06
# 8       256    4.166614e+06
# 9       512    7.998310e+06
# 10     1024    1.677952e+07
# 11     2048    3.646748e+07
# 12     4096    8.412024e+07
# 13     8192    1.945738e+08
# 14    16384    4.951612e+08

# %%
df = pd.read_csv("./result/aulid_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000

df["IOPS"] = fixed_ios / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# Out:
#     threads  avg_latency_ns
# 0         1    1.434878e+05
# 1         2    1.584476e+05
# 2         4    1.660597e+05
# 3         8    1.754599e+05
# 4        16    2.174186e+05
# 5        32    3.110889e+05
# 6        64    4.783304e+05
# 7       128    8.732526e+05
# 8       256    1.723260e+06
# 9       512    3.461200e+06
# 10     1024    7.839362e+06
# 11     2048    1.560892e+07
# 12     4096    3.350967e+07
# 13     8192    6.395460e+07
# 14    16384    1.490987e+08

# %%
df = pd.read_csv("./result/bptree_multithread.csv")

# fixed_ios = 1014295
fixed_ios = 1000000
scale = 3

df["IOPS"] = fixed_ios*scale / df["avg_walltime_s"]
iops_summary = df.groupby("threads")["IOPS"].mean().reset_index()
latency_summary = df.groupby("threads")["avg_latency_ns"].mean().reset_index()
# print(iops_summary)
print(latency_summary)
# Out:
#     threads  avg_latency_ns
# 0         1       178051.37
# 1         2        96944.75
# 2         4        59188.10
# 3         8        41706.99
# 4        16        40131.40
# 5        32        40138.11
# 6        64        40061.42
# 7       128        40040.16
# 8       256        40034.50
# 9       512        39962.70
# 10     1024        40100.53
# 11     2048        40033.50
# 12     4096        40028.82
# 13     8192        40035.16
# 14    16384        40054.10
